# %% [markdown]
# **Test Cell to Run Commands / Change Directories**

# %%
# !cd
# Out:
# C:\Users\bicaj

# %% [markdown]
# -----------------------------------------------------------------

# %% [markdown]
# -------------------------------------------------------------------

# %%
import os
import tensorflow
import warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

print(tensorflow.__version__)
# Out:
# 1.15.0

# %%
# !pip install bert-tensorflow natural-questions --no-dependencies
# Out:
# ...
#      |████████████████████████████████| 71kB 3.3MB/s
# ...

# %%
# !gcloud auth login
# !gcloud auth activate-service-account --key-file ../authentication/credentials-key.json

from google.cloud import storage
from google.cloud.storage import Blob

# Function to explicitly authenticate to GCP storage 
def explicit():
    from google.cloud import storage

    # Explicitly use service account credentials by specifying the private key
    # file.
    storage_client = storage.Client.from_service_account_json('../authentication/credentials-key.json')

    # Make an authenticated API request
    buckets = list(storage_client.list_buckets())
    print(buckets)

explicit()

# Configure and set project & bucket
PROJECT_ID = "natural-questions-v1" #@param {type:"string"}
# !gcloud config set project $PROJECT_ID

# Configure bucket & region
BUCKET_NAME = "nq-challenge-bucket" #@param {type:"string"}
REGION = "us-east4" #@param {type:"string"}

# !gsutil ls -al gs://$BUCKET_NAME/bert_joint/
PROJECT_DIR = "gs://nq-challenge-bucket/bert_joint/"

# %%
# Verify that GPU is enabled
# !python verify_gpu.py
# Out:
# 2020-03-25 05:36:23.471012: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-03-25 05:36:23.472996: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3208a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-25 05:36:23.473030: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-25 05:36:23.515866: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-25 05:36:23.696995: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-25 05:36:23.698101: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3208bc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# ...

# %%
# Run inference and compute predictions
# !python run_nq.py
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/bert/optimization.py:87: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# /usr/local/lib/python3.6/dist-packages/absl/flags/_validators.py:359: UserWarning: Flag --vocab_file has a non-None default value; therefore, mark_flag_as_required will pass even if flag is not specified in the command line!
#   'command line!' % flag_name)
# /usr/local/lib/python3.6/dist-packages/absl/flags/_validators.py:359: UserWarning: Flag --bert_config_file has a non-None default value; therefore, mark_flag_as_required will pass even if flag is not specified in the command line!
#   'command line!' % flag_name)
# /usr/local/lib/python3.6/dist-packages/absl/flags/_validators.py:359: UserWarning: Flag --output_dir has a non-None default value; therefore, mark_flag_as_required will pass even if flag is not specified in the command line!
#   'command line!' % flag_name)
# ...

# %%
# Evaluate predictions and compute scores
# !python nq_eval.py
# Out:
# /usr/local/lib/python3.6/dist-packages/absl/flags/_validators.py:359: UserWarning: Flag --gold_path has a non-None default value; therefore, mark_flag_as_required will pass even if flag is not specified in the command line!
#   'command line!' % flag_name)
# /usr/local/lib/python3.6/dist-packages/absl/flags/_validators.py:359: UserWarning: Flag --predictions_path has a non-None default value; therefore, mark_flag_as_required will pass even if flag is not specified in the command line!
#   'command line!' % flag_name)
# I0325 06:01:03.356494 140509780744064 eval_utils.py:261] parsing input/nq-dev-sample.jsonl.gz .....
# I0325 06:01:06.565202 140509780744064 eval_utils.py:213] Reading predictions from file: output/predictions-dev-sample.jsonl
# ...
