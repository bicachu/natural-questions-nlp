# %% [markdown]
# #### Overview of Docker Architecture

# %% [markdown]
# ![](img/docker_architecture.png)

# %%
# Set current directory
# %cd /home/jupyter/docker_test
# Out:
# /home/jupyter/docker_test

# %% [markdown]
# #### Run this in TERMINAL to create Dockerfile

# %%
cat <<'HERE' | tee Dockerfile
# Docker file for submission of the BERT-joint baseline to the Natural Questions
# competition site: https://ai.google.com/research/NaturalQuestions/competition.

# use tensorflow version 1.15 and python 3
FROM tensorflow/tensorflow:1.15.0-gpu-py3

# Upgrade pip to avoid errors
RUN pip install --upgrade pip

# Install tqdm
RUN pip install --trusted-host pypi.python.org tqdm
# Install the BERT and Natural Questions libraries.
RUN pip install --trusted-host pypi.python.org bert-tensorflow 
# install with --no-dependencies to avoid wsgiref error
RUN pip install --trusted-host pypi.python.org natural-questions --no-dependencies

# Add everything in the current directory to a /nq_ensemble_model directory in the
# Docker container.
ADD . /nq_model

# %% [markdown]
# #### Run this in TERMINAL to create submission script

# %%
# Create submission.sh 
# !cat <<'HERE' | tee submission.sh
#!/bin/bash
#
# submission.sh: The script to be launched in the Docker image.
#
# Usage: submission.sh <input_data_pattern> <output_file>
#   input_data_pattern: jsonl.gz NQ evaluation files,
#   output_file: json file containing answer key produced by the model.
#
# Sample usage:
#   submission.sh nq-dev-0?.jsonl.gz predictions.json

set -e
set -x

INPUT_PATH=$1
OUTPUT_PATH=$2

cd /nq_model
python3 -m run_nq_ensemble_modified \
  --max_seq_length=512 \
  --doc_stride=256 \
  --max_contexts=48 \
  --output_dir="/nq_model/output" \
  --predict_file="$INPUT_PATH"  \
  --final_output_prediction_file="$OUTPUT_PATH"

# %%
# %%time
# Build the Docker image using Dockerfile and submission.sh in the current directory
IMAGE_NAME="nq-submission-bert-ensemble-newtf"
# !docker build --tag=$IMAGE_NAME .
# Out:
# Sending build context to Docker daemon  12.08GB
# Step 1/6 : FROM tensorflow/tensorflow:1.15.0-gpu-py3
# 1.15.0-gpu-py3: Pulling from tensorflow/tensorflow
#
# 02085707: Pulling fs layer
# 5509d51d: Pulling fs layer
# 9fe70a46: Pulling fs layer
# e1789921: Pulling fs layer
# e1789921: Waiting fs layer
# fcda1e6e: Pulling fs layer
# a76e3193: Pulling fs layer
# c69d85cf: Pulling fs layer
# 1467f169: Pulling fs layer
# bd4663fe: Pulling fs layer
# dba96c29: Pulling fs layer
# 7e08066b: Pulling fs layer
# 8a00ccc9: Pulling fs layer
# ef1817a6: Pulling fs layer
# 54337004: Pulling fs layer
# Digest: sha256:9a754acdbe22901b06e716887bb95257cda7db79af61c59a68facf207bd73161
# Status: Downloaded newer image for tensorflow/tensorflow:1.15.0-gpu-py3
#  ---> e544497892a3
# Step 2/6 : RUN pip install --upgrade pip
#  ---> Running in 07a80fc21e33
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/54/0c/d01aa759fdc501a58f431eb594a17495f15b88da142ce14b5845662c13f3/pip-20.0.2-py2.py3-none-any.whl (1.4MB)
# Installing collected packages: pip
#   Found existing installation: pip 19.3.1
#     Uninstalling pip-19.3.1:
#       Successfully uninstalled pip-19.3.1
# Successfully installed pip-20.0.2
# Removing intermediate container 07a80fc21e33
#  ---> afc72f7cd746
# Step 3/6 : RUN pip install --trusted-host pypi.python.org tqdm
#  ---> Running in 90d06e8d96e6
# Collecting tqdm
#   Downloading tqdm-4.45.0-py2.py3-none-any.whl (60 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.45.0
# Removing intermediate container 90d06e8d96e6
#  ---> a711eb579d22
# Step 4/6 : RUN pip install --trusted-host pypi.python.org bert-tensorflow
#  ---> Running in 344cdda52d54
# Collecting bert-tensorflow
#   Downloading bert_tensorflow-1.0.1-py2.py3-none-any.whl (67 kB)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from bert-tensorflow) (1.11.0)
# Installing collected packages: bert-tensorflow
# Successfully installed bert-tensorflow-1.0.1
# Removing intermediate container 344cdda52d54
#  ---> c3cb27a27ed8
# Step 5/6 : RUN pip install --trusted-host pypi.python.org natural-questions --no-dependencies
#  ---> Running in c6a6cf011a0f
# Collecting natural-questions
#   Downloading natural_questions-1.0.4-py2.py3-none-any.whl (22 kB)
# Installing collected packages: natural-questions
# Successfully installed natural-questions-1.0.4
# Removing intermediate container c6a6cf011a0f
#  ---> a1afb688c8fb
# Step 6/6 : ADD . /nq_model
#  ---> 3170647395f2
# Successfully built 3170647395f2
# Successfully tagged nq-submission-bert-ensemble-newtf:latest
# CPU times: user 14.1 s, sys: 2.5 s, total: 16.6 s
# Wall time: 12min 32s

# %% [markdown]
# #### Test Docker image on  dev set sample

# %%
# %%time
# Mount the small dev-sample into a temporary directory within the container
DATA_DIR="/tmp/nq-submission-test-data"
# !mkdir -p "$DATA_DIR"
# !gsutil cp -R "gs://bert-nq/tiny-dev" "$DATA_DIR"

# Run the Docker image with dev set as input and predictions.json as output
# !docker run --runtime=nvidia -a stdin -a stdout -a stderr -v "$DATA_DIR":/data \
    "$IMAGE_NAME" bash "/nq_model/submission.sh" \
    "/data/tiny-dev/nq-dev-sample.no-annot.jsonl.gz" \
    "/data/predictions-newtf.json"
# Out:
# Copying gs://bert-nq/tiny-dev/nq-dev-sample.jsonl.gz...
# Copying gs://bert-nq/tiny-dev/nq-dev-sample.no-annot.jsonl.gz...
# - [2 files][ 50.2 MiB/ 50.2 MiB]
# Operation completed over 2 objects/50.2 MiB.
# + INPUT_PATH=/data/tiny-dev/nq-dev-sample.no-annot.jsonl.gz
# + OUTPUT_PATH=/data/predictions-newtf.json
# + cd /nq_model
# + python3 -m run_nq_ensemble --max_seq_length=512 --doc_stride=256 --max_contexts=48 --output_dir=/nq_model/output --predict_file=/data/tiny-dev/nq-dev-sample.no-annot.jsonl.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/bert/optimization.py:87: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /nq_model/run_nq_ensemble.py:1164: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# WARNING:tensorflow:From /nq_model/run_nq_ensemble.py:1174: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# WARNING:tensorflow:From /nq_model/run_nq_ensemble.py:1392: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /nq_model/run_nq_ensemble.py:1392: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/bert/modeling.py:93: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /nq_model/run_nq_ensemble.py:1395: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f1ed8fdf840>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Using config: {'_model_dir': '/nq_model/output', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 1000, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 100, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1ed1effb38>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=1000, num_shards=8, num_cores_per_replica=None, per_host_input_for_training=3, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None, eval_training_input_configuration=2, experimental_host_call_every_n_steps=1), '_cluster': None}
# INFO:tensorflow:_TPUContext: eval_on_tpu True
# WARNING:tensorflow:eval_on_tpu ignored because use_tpu is False.
# WARNING:tensorflow:From /nq_model/run_nq_ensemble.py:1358: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# 100%|██████████| 200/200 [00:28<00:00,  7.11it/s]
# INFO:tensorflow:***** Running predictions *****
# INFO:tensorflow:  Num orig examples = 200
# INFO:tensorflow:  Batch size = 8
# WARNING:tensorflow:From /nq_model/run_nq_ensemble.py:1304: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# WARNING:tensorflow:From /nq_model/run_nq_ensemble.py:1474: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
#   0%|          | 0/3075 [00:00<?, ?it/s]INFO:tensorflow:Could not find trained model in model_dir: /nq_model/output, running initialization to predict.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /nq_model/run_nq_ensemble.py:1344: map_and_batch (from tensorflow.python.data.experimental.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map(map_func, num_parallel_calls)` followed by `tf.data.Dataset.batch(batch_size, drop_remainder)`. Static tf.data optimizations will take care of using the fused implementation.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# WARNING:tensorflow:From /nq_model/run_nq_ensemble.py:1324: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running infer on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 512)
# INFO:tensorflow:  name = input_mask, shape = (?, 512)
# INFO:tensorflow:  name = segment_ids, shape = (?, 512)
# INFO:tensorflow:  name = unique_ids, shape = (?,)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /nq_model/run_nq_ensemble.py:1216: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /nq_model/run_nq_ensemble.py:1231: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:  name = bert/embeddings/word_embeddings:0, shape = (30522, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/embeddings/token_type_embeddings:0, shape = (2, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/embeddings/position_embeddings:0, shape = (512, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/embeddings/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/embeddings/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_0/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_0/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_0/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_0/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_0/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_0/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_0/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_0/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_0/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_0/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_0/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_0/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_0/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_0/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_0/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_0/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_1/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_1/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_1/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_1/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_1/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_1/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_1/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_1/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_1/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_1/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_1/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_1/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_1/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_1/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_1/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_1/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_2/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_2/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_2/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_2/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_2/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_2/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_2/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_2/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_2/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_2/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_2/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_2/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_2/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_2/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_2/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_2/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_3/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_3/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_3/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_3/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_3/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_3/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_3/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_3/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_3/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_3/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_3/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_3/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_3/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_3/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_3/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_3/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_4/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_4/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_4/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_4/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_4/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_4/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_4/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_4/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_4/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_4/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_4/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_4/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_4/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_4/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_4/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_4/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_5/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_5/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_5/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_5/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_5/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_5/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_5/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_5/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_5/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_5/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_5/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_5/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_5/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_5/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_5/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_5/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_6/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_6/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_6/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_6/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_6/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_6/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_6/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_6/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_6/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_6/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_6/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_6/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_6/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_6/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_6/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_6/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_7/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_7/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_7/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_7/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_7/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_7/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_7/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_7/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_7/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_7/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_7/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_7/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_7/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_7/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_7/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_7/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_8/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_8/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_8/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_8/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_8/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_8/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_8/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_8/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_8/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_8/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_8/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_8/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_8/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_8/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_8/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_8/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_9/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_9/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_9/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_9/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_9/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_9/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_9/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_9/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_9/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_9/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_9/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_9/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_9/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_9/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_9/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_9/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_10/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_10/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_10/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_10/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_10/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_10/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_10/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_10/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_10/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_10/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_10/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_10/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_10/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_10/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_10/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_10/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_11/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_11/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_11/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_11/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_11/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_11/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_11/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_11/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_11/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_11/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_11/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_11/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_11/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_11/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_11/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_11/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_12/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_12/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_12/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_12/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_12/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_12/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_12/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_12/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_12/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_12/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_12/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_12/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_12/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_12/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_12/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_12/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_13/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_13/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_13/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_13/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_13/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_13/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_13/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_13/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_13/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_13/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_13/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_13/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_13/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_13/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_13/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_13/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_14/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_14/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_14/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_14/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_14/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_14/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_14/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_14/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_14/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_14/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_14/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_14/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_14/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_14/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_14/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_14/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_15/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_15/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_15/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_15/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_15/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_15/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_15/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_15/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_15/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_15/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_15/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_15/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_15/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_15/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_15/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_15/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_16/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_16/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_16/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_16/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_16/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_16/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_16/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_16/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_16/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_16/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_16/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_16/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_16/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_16/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_16/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_16/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_17/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_17/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_17/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_17/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_17/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_17/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_17/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_17/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_17/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_17/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_17/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_17/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_17/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_17/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_17/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_17/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_18/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_18/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_18/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_18/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_18/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_18/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_18/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_18/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_18/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_18/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_18/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_18/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_18/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_18/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_18/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_18/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_19/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_19/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_19/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_19/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_19/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_19/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_19/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_19/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_19/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_19/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_19/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_19/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_19/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_19/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_19/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_19/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_20/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_20/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_20/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_20/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_20/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_20/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_20/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_20/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_20/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_20/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_20/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_20/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_20/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_20/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_20/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_20/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_21/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_21/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_21/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_21/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_21/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_21/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_21/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_21/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_21/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_21/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_21/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_21/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_21/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_21/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_21/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_21/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_22/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_22/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_22/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_22/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_22/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_22/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_22/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# INFO:tensorflow:  name = bert/encoder/layer_22/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# ...
# 2020-04-13 18:03:57.087918: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x7f1e00839600 next 64 of size 16777216
# 2020-04-13 18:03:57.087934: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x7f1e01839600 next 65 of size 4194304
# 2020-04-13 18:03:57.087951: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x7f1e01c39600 next 66 of size 4096
# 2020-04-13 18:03:57.087966: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x7f1e01c3a600 next 67 of size 4194304
# 2020-04-13 18:03:57.087984: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x7f1e0203a600 next 68 of size 4194304
# 2020-04-13 18:03:57.087996: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x7f1e0243a600 next 69 of size 16384
# 2020-04-13 18:03:57.088009: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x7f1e0243e600 next 70 of size 4096
# 2020-04-13 18:03:57.088026: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x7f1e0243f600 next 71 of size 4194304
# 2020-04-13 18:03:57.088042: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x7f1e0283f600 next 72 of size 4096
# 2020-04-13 18:03:57.088058: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x7f1e02840600 next 73 of size 4096
# 2020-04-13 18:03:57.088075: I tensorflow/core/common_runtime/bfc_allocator.cc:905] InUse at 0x7f1e02841600 next 18446744073709551615 of size 7989760
# 2020-04-13 18:03:57.088087: I tensorflow/core/common_runtime/bfc_allocator.cc:914]      Summary of in-use Chunks by size:
# 2020-04-13 18:03:57.088105: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 256 totalling 256B
# 2020-04-13 18:03:57.088121: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 1280 totalling 1.2KiB
# 2020-04-13 18:03:57.088140: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 41 Chunks of size 4096 totalling 164.0KiB
# 2020-04-13 18:03:57.088158: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 6 Chunks of size 16384 totalling 96.0KiB
# 2020-04-13 18:03:57.088175: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 18 Chunks of size 4194304 totalling 72.00MiB
# 2020-04-13 18:03:57.088193: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 1 Chunks of size 7989760 totalling 7.62MiB
# 2020-04-13 18:03:57.088205: I tensorflow/core/common_runtime/bfc_allocator.cc:917] 6 Chunks of size 16777216 totalling 96.00MiB
# 2020-04-13 18:03:57.088218: I tensorflow/core/common_runtime/bfc_allocator.cc:921] Sum Total of in-use chunks: 175.88MiB
# 2020-04-13 18:03:57.088235: I tensorflow/core/common_runtime/bfc_allocator.cc:923] total_region_allocated_bytes_: 184418304 memory_limit_: 184418304 available bytes: 0 curr_region_allocation_bytes_: 368836608
# 2020-04-13 18:03:57.088253: I tensorflow/core/common_runtime/bfc_allocator.cc:929] Stats:
# Limit:                   184418304
# InUse:                   184418304
# MaxInUse:                184418304
# NumAllocs:                      74
# MaxAllocSize:             16777216
#
# 2020-04-13 18:03:57.088275: W tensorflow/core/common_runtime/bfc_allocator.cc:424] **************************************************************************************************xx
# ERROR:tensorflow:Error recorded from prediction_loop: Dst tensor is not initialized.
# 	 [[node checkpoint_initializer_257 (defined at usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py:1748) ]]
#
# Original stack trace for 'checkpoint_initializer_257':
#   File "usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "nq_model/run_nq_ensemble.py", line 1535, in <module>
#     main()
#   File "nq_model/run_nq_ensemble.py", line 1482, in main
#     predict_input_fn, yield_single_examples=True), total=len(eval_features)):
#   File "usr/local/lib/python3.6/dist-packages/tqdm/std.py", line 1127, in __iter__
#     for obj in iterable:
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 3072, in predict
#     yield_single_examples=yield_single_examples):
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py", line 622, in predict
#     features, None, ModeKeys.PREDICT, self.config)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 2857, in _call_model_fn
#     config)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py", line 1149, in _call_model_fn
#     model_fn_results = self._model_fn(features=features, **kwargs)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 3126, in _model_fn
#     features, labels, is_export_mode=is_export_mode)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 1663, in call_without_tpu
#     return self._call_model_fn(features, labels, is_export_mode=is_export_mode)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 1994, in _call_model_fn
#     estimator_spec = self._model_fn(features=features, **kwargs)
#   File "nq_model/run_nq_ensemble.py", line 1231, in model_fn
#     tf.train.init_from_checkpoint(init_checkpoint, assignment_map)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/checkpoint_utils.py", line 291, in init_from_checkpoint
#     init_from_checkpoint_fn)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/distribute/distribute_lib.py", line 1940, in merge_call
#     return self._merge_call(merge_fn, args, kwargs)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/distribute/distribute_lib.py", line 1947, in _merge_call
#     return merge_fn(self._strategy, *args, **kwargs)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/checkpoint_utils.py", line 286, in <lambda>
#     ckpt_dir_or_file, assignment_map)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/checkpoint_utils.py", line 334, in _init_from_checkpoint
#     _set_variable_or_list_initializer(var, ckpt_file, tensor_name_in_ckpt)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/checkpoint_utils.py", line 458, in _set_variable_or_list_initializer
#     _set_checkpoint_initializer(variable_or_list, ckpt_file, tensor_name, "")
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/checkpoint_utils.py", line 412, in _set_checkpoint_initializer
#     ckpt_file, [tensor_name], [slice_spec], [base_type], name=name)[0]
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/gen_io_ops.py", line 1696, in restore_v2
#     name=name)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/op_def_library.py", line 794, in _apply_op_helper
#     op_def=op_def)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# INFO:tensorflow:prediction_loop marked as finished
# WARNING:tensorflow:Reraising captured error
#   0%|          | 0/3075 [00:20<?, ?it/s]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 1365, in _do_call
#     return fn(*args)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 1350, in _run_fn
#     target_list, run_metadata)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 1443, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.InternalError: Dst tensor is not initialized.
# 	 [[{{node checkpoint_initializer_257}}]]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/nq_model/run_nq_ensemble.py", line 1535, in <module>
#     main()
#   File "/nq_model/run_nq_ensemble.py", line 1482, in main
#     predict_input_fn, yield_single_examples=True), total=len(eval_features)):
#   File "/usr/local/lib/python3.6/dist-packages/tqdm/std.py", line 1127, in __iter__
#     for obj in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 3078, in predict
#     rendezvous.raise_errors()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/tpu/error_handling.py", line 136, in raise_errors
#     six.reraise(typ, value, traceback)
#   File "/usr/lib/python3/dist-packages/six.py", line 693, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 3072, in predict
#     yield_single_examples=yield_single_examples):
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py", line 638, in predict
#     hooks=all_hooks) as mon_sess:
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py", line 1014, in __init__
#     stop_grace_period_secs=stop_grace_period_secs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py", line 725, in __init__
#     self._sess = _RecoverableSession(self._coordinated_creator)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py", line 1207, in __init__
#     _WrappedSession.__init__(self, self._create_session())
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py", line 1212, in _create_session
#     return self._sess_creator.create_session()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py", line 878, in create_session
#     self.tf_sess = self._session_creator.create_session()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py", line 647, in create_session
#     init_fn=self._scaffold.init_fn)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/session_manager.py", line 296, in prepare_session
#     sess.run(init_op, feed_dict=init_feed_dict)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 956, in run
#     run_metadata_ptr)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 1180, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 1359, in _do_run
#     run_metadata)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 1384, in _do_call
#     raise type(e)(node_def, op, message)
# tensorflow.python.framework.errors_impl.InternalError: Dst tensor is not initialized.
# 	 [[node checkpoint_initializer_257 (defined at usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py:1748) ]]
#
# Original stack trace for 'checkpoint_initializer_257':
#   File "usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "nq_model/run_nq_ensemble.py", line 1535, in <module>
#     main()
#   File "nq_model/run_nq_ensemble.py", line 1482, in main
#     predict_input_fn, yield_single_examples=True), total=len(eval_features)):
#   File "usr/local/lib/python3.6/dist-packages/tqdm/std.py", line 1127, in __iter__
#     for obj in iterable:
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 3072, in predict
#     yield_single_examples=yield_single_examples):
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py", line 622, in predict
#     features, None, ModeKeys.PREDICT, self.config)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 2857, in _call_model_fn
#     config)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py", line 1149, in _call_model_fn
#     model_fn_results = self._model_fn(features=features, **kwargs)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 3126, in _model_fn
#     features, labels, is_export_mode=is_export_mode)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 1663, in call_without_tpu
#     return self._call_model_fn(features, labels, is_export_mode=is_export_mode)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 1994, in _call_model_fn
#     estimator_spec = self._model_fn(features=features, **kwargs)
#   File "nq_model/run_nq_ensemble.py", line 1231, in model_fn
#     tf.train.init_from_checkpoint(init_checkpoint, assignment_map)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/checkpoint_utils.py", line 291, in init_from_checkpoint
#     init_from_checkpoint_fn)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/distribute/distribute_lib.py", line 1940, in merge_call
#     return self._merge_call(merge_fn, args, kwargs)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/distribute/distribute_lib.py", line 1947, in _merge_call
#     return merge_fn(self._strategy, *args, **kwargs)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/checkpoint_utils.py", line 286, in <lambda>
#     ckpt_dir_or_file, assignment_map)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/checkpoint_utils.py", line 334, in _init_from_checkpoint
#     _set_variable_or_list_initializer(var, ckpt_file, tensor_name_in_ckpt)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/checkpoint_utils.py", line 458, in _set_variable_or_list_initializer
#     _set_checkpoint_initializer(variable_or_list, ckpt_file, tensor_name, "")
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/checkpoint_utils.py", line 412, in _set_checkpoint_initializer
#     ckpt_file, [tensor_name], [slice_spec], [base_type], name=name)[0]
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/gen_io_ops.py", line 1696, in restore_v2
#     name=name)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/op_def_library.py", line 794, in _apply_op_helper
#     op_def=op_def)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# CPU times: user 1.17 s, sys: 252 ms, total: 1.42 s
# Wall time: 1min 10s

# %%
# %%time
# Mount the small dev-sample into a temporary directory within the container
DATA_DIR="/tmp/nq-submission-test-data"
# !mkdir -p "$DATA_DIR"
# !gsutil cp -R "gs://bert-nq/tiny-dev" "$DATA_DIR"

# !docker run --runtime=nvidia -a stdin -a stdout -a stderr -v "$DATA_DIR":/data \
    "$IMAGE_NAME" bash "/nq_model/submission.sh" \
    "/data/tiny-dev/nq-dev-sample.no-annot.jsonl.gz" \
    "/data/predictions-td-no-annot.json"
# Out:
# Copying gs://bert-nq/tiny-dev/nq-dev-sample.jsonl.gz...
# Copying gs://bert-nq/tiny-dev/nq-dev-sample.no-annot.jsonl.gz...
# - [2 files][ 50.2 MiB/ 50.2 MiB]
# Operation completed over 2 objects/50.2 MiB.
# + INPUT_PATH=/data/tiny-dev/nq-dev-sample.no-annot.jsonl.gz
# + OUTPUT_PATH=/data/predictions-td-no-annot.json
# + cd /nq_model
# + python3 -m run_nq_ensemble --max_seq_length=512 --doc_stride=256 --max_contexts=48 --output_dir=/nq_model/output --predict_file=/data/tiny-dev/nq-dev-sample.no-annot.jsonl.gz
# WARNING: Logging before flag parsing goes to stderr.
# W0413 15:56:37.050721 140719534966592 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/bert/optimization.py:87: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0413 15:56:37.486640 140719534966592 deprecation_wrapper.py:119] From /nq_model/run_nq_ensemble.py:1164: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# W0413 15:56:37.487611 140719534966592 deprecation_wrapper.py:119] From /nq_model/run_nq_ensemble.py:1174: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W0413 15:56:50.496580 140719534966592 deprecation_wrapper.py:119] From /nq_model/run_nq_ensemble.py:1392: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0413 15:56:50.496814 140719534966592 deprecation_wrapper.py:119] From /nq_model/run_nq_ensemble.py:1392: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W0413 15:56:50.496936 140719534966592 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/bert/modeling.py:93: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0413 15:56:50.497603 140719534966592 deprecation_wrapper.py:119] From /nq_model/run_nq_ensemble.py:1395: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# W0413 15:56:50.632893 140719534966592 estimator.py:1984] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7ffb796bb7b8>) includes params argument, but params are not passed to Estimator.
# I0413 15:56:50.634675 140719534966592 estimator.py:209] Using config: {'_model_dir': '/nq_model/output', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 1000, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 100, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ffb739da080>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=1000, num_shards=8, num_cores_per_replica=None, per_host_input_for_training=3, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None, eval_training_input_configuration=2), '_cluster': None}
# I0413 15:56:50.635611 140719534966592 tpu_context.py:209] _TPUContext: eval_on_tpu True
# W0413 15:56:50.636211 140719534966592 tpu_context.py:211] eval_on_tpu ignored because use_tpu is False.
# W0413 15:56:50.636460 140719534966592 deprecation_wrapper.py:119] From /nq_model/run_nq_ensemble.py:1358: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# 100%|██████████| 200/200 [00:26<00:00,  7.65it/s]
# I0413 15:57:16.770640 140719534966592 run_nq_ensemble.py:1461] ***** Running predictions *****
# I0413 15:57:16.770869 140719534966592 run_nq_ensemble.py:1462]   Num orig examples = 200
# I0413 15:57:16.771534 140719534966592 run_nq_ensemble.py:1464]   Batch size = 8
# W0413 15:57:16.771748 140719534966592 deprecation_wrapper.py:119] From /nq_model/run_nq_ensemble.py:1304: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# W0413 15:57:16.772000 140719534966592 deprecation.py:323] From /nq_model/run_nq_ensemble.py:1474: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
#   0%|          | 0/3075 [00:00<?, ?it/s]I0413 15:57:17.032407 140719534966592 estimator.py:612] Could not find trained model in model_dir: /nq_model/output, running initialization to predict.
# W0413 15:57:17.059540 140719534966592 deprecation.py:323] From /nq_model/run_nq_ensemble.py:1344: map_and_batch (from tensorflow.python.data.experimental.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map(map_func, num_parallel_calls)` followed by `tf.data.Dataset.batch(batch_size, drop_remainder)`. Static tf.data optimizations will take care of using the fused implementation.
# W0413 15:57:17.061219 140719534966592 deprecation_wrapper.py:119] From /nq_model/run_nq_ensemble.py:1317: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# W0413 15:57:17.065205 140719534966592 deprecation.py:323] From /nq_model/run_nq_ensemble.py:1324: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# I0413 15:57:17.084990 140719534966592 estimator.py:1145] Calling model_fn.
# I0413 15:57:17.085202 140719534966592 tpu_estimator.py:2965] Running infer on CPU
# I0413 15:57:17.085656 140719534966592 run_nq_ensemble.py:1197] *** Features ***
# I0413 15:57:17.085838 140719534966592 run_nq_ensemble.py:1199]   name = input_ids, shape = (?, 512)
# I0413 15:57:17.085957 140719534966592 run_nq_ensemble.py:1199]   name = input_mask, shape = (?, 512)
# I0413 15:57:17.086084 140719534966592 run_nq_ensemble.py:1199]   name = segment_ids, shape = (?, 512)
# I0413 15:57:17.086193 140719534966592 run_nq_ensemble.py:1199]   name = unique_ids, shape = (?,)
# W0413 15:57:17.089838 140719534966592 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/bert/modeling.py:171: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0413 15:57:17.091636 140719534966592 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/bert/modeling.py:409: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0413 15:57:17.124521 140719534966592 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/bert/modeling.py:490: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# W0413 15:57:17.274016 140719534966592 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/bert/modeling.py:671: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0413 15:57:22.417403 140719534966592 deprecation_wrapper.py:119] From /nq_model/run_nq_ensemble.py:1231: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# I0413 15:57:23.841659 140719534966592 run_nq_ensemble.py:1233] **** Trainable Variables ****
# I0413 15:57:23.841863 140719534966592 run_nq_ensemble.py:1239]   name = bert/embeddings/word_embeddings:0, shape = (30522, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.842000 140719534966592 run_nq_ensemble.py:1239]   name = bert/embeddings/token_type_embeddings:0, shape = (2, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.842124 140719534966592 run_nq_ensemble.py:1239]   name = bert/embeddings/position_embeddings:0, shape = (512, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.842243 140719534966592 run_nq_ensemble.py:1239]   name = bert/embeddings/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.842351 140719534966592 run_nq_ensemble.py:1239]   name = bert/embeddings/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.842450 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_0/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.842557 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_0/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.842690 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_0/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.842796 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_0/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.842896 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_0/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.842997 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_0/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.843091 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_0/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.843184 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_0/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.843260 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_0/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.843344 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_0/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.843432 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_0/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 15:57:23.843519 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_0/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 15:57:23.843606 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_0/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.843694 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_0/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.843789 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_0/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.843887 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_0/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.843975 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_1/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.844089 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_1/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.844181 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_1/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.844278 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_1/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.844366 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_1/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.844452 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_1/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.844542 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_1/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.844636 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_1/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.844721 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_1/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.844811 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_1/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.844904 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_1/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 15:57:23.845001 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_1/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 15:57:23.845098 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_1/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.845184 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_1/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.845268 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_1/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.845353 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_1/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.845441 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_2/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.845540 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_2/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.845627 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_2/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.845723 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_2/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.845806 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_2/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.845903 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_2/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.846005 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_2/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.846104 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_2/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.846193 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_2/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.846278 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_2/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.846369 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_2/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 15:57:23.846466 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_2/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 15:57:23.846557 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_2/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.846680 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_2/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.846780 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_2/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.846877 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_2/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.846973 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_3/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.847083 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_3/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.847166 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_3/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.847253 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_3/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.847345 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_3/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.847444 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_3/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.847534 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_3/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.847634 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_3/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.847719 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_3/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.847807 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_3/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.847901 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_3/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 15:57:23.847998 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_3/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 15:57:23.848098 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_3/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.848190 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_3/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.848274 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_3/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.848352 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_3/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.848437 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_4/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.848541 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_4/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.848637 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_4/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.848724 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_4/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.848814 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_4/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.848915 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_4/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.849014 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_4/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.849101 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_4/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.849191 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_4/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.849280 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_4/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.849371 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_4/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 15:57:23.849460 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_4/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 15:57:23.849547 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_4/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.849649 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_4/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.849746 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_4/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.849830 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_4/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.849913 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_5/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.850019 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_5/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.850110 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_5/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.850209 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_5/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.850305 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_5/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.850397 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_5/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.850484 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_5/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.850574 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_5/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.850677 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_5/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.850759 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_5/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.850850 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_5/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 15:57:23.850941 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_5/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 15:57:23.851037 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_5/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.851127 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_5/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.851222 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_5/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.851312 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_5/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.851403 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_6/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.851493 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_6/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.851583 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_6/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.851675 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_6/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.851775 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_6/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.851868 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_6/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.851960 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_6/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.852058 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_6/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.852149 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_6/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.852233 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_6/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.852325 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_6/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 15:57:23.852422 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_6/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 15:57:23.852505 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_6/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.852609 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_6/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.852711 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_6/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.852799 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_6/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.852895 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_7/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.852996 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_7/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.853094 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_7/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.853191 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_7/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.853278 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_7/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.853370 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_7/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.853461 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_7/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.853558 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_7/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.853647 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_7/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.853729 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_7/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.853814 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_7/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 15:57:23.853903 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_7/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 15:57:23.854000 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_7/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.854100 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_7/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.854188 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_7/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.854275 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_7/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.854362 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_8/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.854457 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_8/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.854541 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_8/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.854665 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_8/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.854763 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_8/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.854864 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_8/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.854944 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_8/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.855041 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_8/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.855138 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_8/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.855234 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_8/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.855324 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_8/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 15:57:23.855416 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_8/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 15:57:23.855519 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_8/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.855650 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_8/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.855734 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_8/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.855818 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_8/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.855904 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_9/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.856009 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_9/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.856102 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_9/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.856235 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_9/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.856339 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_9/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.856449 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_9/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.856557 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_9/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.856656 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_9/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.856774 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_9/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.856878 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_9/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.856981 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_9/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 15:57:23.857105 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_9/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 15:57:23.857213 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_9/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.857322 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_9/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.857433 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_9/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.857536 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_9/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.857641 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_10/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.857741 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_10/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.857844 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_10/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.857946 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_10/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.858055 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_10/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.858166 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_10/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.858271 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_10/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.858379 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_10/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.858480 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_10/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.858583 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_10/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.858724 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_10/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 15:57:23.858848 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_10/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 15:57:23.858958 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_10/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.859088 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_10/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.859197 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_10/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.859291 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_10/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.859381 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_11/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.859498 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_11/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.859615 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_11/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.859722 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_11/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.859815 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_11/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.859928 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_11/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.860034 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_11/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.860132 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_11/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.860217 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_11/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.860307 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_11/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.860395 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_11/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 15:57:23.860497 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_11/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 15:57:23.860587 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_11/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.860685 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_11/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.860776 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_11/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.860865 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_11/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.860953 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_12/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.861045 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_12/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.861139 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_12/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.861228 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_12/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.861315 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_12/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.861399 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_12/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.861480 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_12/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.861570 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_12/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.861657 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_12/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.861751 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_12/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.861835 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_12/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 15:57:23.861924 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_12/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 15:57:23.862026 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_12/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.862127 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_12/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.862212 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_12/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.862302 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_12/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.862383 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_13/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.862480 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_13/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.862563 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_13/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.862684 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_13/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.862780 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_13/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.862879 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_13/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.862977 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_13/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.863087 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_13/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.863178 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_13/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.863272 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_13/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.863363 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_13/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 15:57:23.863456 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_13/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 15:57:23.863556 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_13/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.863644 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_13/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.863728 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_13/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.863808 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_13/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.863894 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_14/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.863996 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_14/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.864094 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_14/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.864189 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_14/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.864275 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_14/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.864365 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_14/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.864453 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_14/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.864538 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_14/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.864623 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_14/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.864706 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_14/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.864799 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_14/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 15:57:23.864899 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_14/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 15:57:23.865005 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_14/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.865110 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_14/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.865198 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_14/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.865282 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_14/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.865373 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_15/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.865469 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_15/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.865559 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_15/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.865649 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_15/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.865742 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_15/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.865829 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_15/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.865911 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_15/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 15:57:23.866020 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_15/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.866118 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_15/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 15:57:23.866208 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_15/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# ...
# I0413 16:05:18.499373 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_21/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 16:05:18.499460 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_21/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.499546 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_21/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 16:05:18.499639 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_21/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.499735 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_21/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.499829 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_21/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.499925 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_21/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 16:05:18.500041 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_21/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 16:05:18.500141 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_21/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 16:05:18.500238 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_21/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.500332 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_21/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.500430 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_21/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.500520 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_22/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 16:05:18.500615 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_22/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.500702 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_22/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 16:05:18.500788 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_22/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.500864 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_22/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 16:05:18.500942 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_22/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.501024 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_22/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 16:05:18.501103 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_22/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.501177 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_22/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.501250 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_22/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.501322 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_22/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 16:05:18.501399 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_22/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 16:05:18.501471 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_22/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 16:05:18.501550 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_22/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.501623 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_22/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.501691 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_22/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.501760 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_23/attention/self/query/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 16:05:18.501837 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_23/attention/self/query/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.501909 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_23/attention/self/key/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 16:05:18.501984 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_23/attention/self/key/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.502074 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_23/attention/self/value/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 16:05:18.502156 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_23/attention/self/value/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.502229 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_23/attention/output/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 16:05:18.502304 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_23/attention/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.502374 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_23/attention/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.502441 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_23/attention/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.502510 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_23/intermediate/dense/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0413 16:05:18.502585 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_23/intermediate/dense/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0413 16:05:18.502689 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_23/output/dense/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0413 16:05:18.502763 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_23/output/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.502833 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_23/output/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.502905 140719534966592 run_nq_ensemble.py:1239]   name = bert/encoder/layer_23/output/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.502975 140719534966592 run_nq_ensemble.py:1239]   name = bert/pooler/dense/kernel:0, shape = (1024, 1024), *INIT_FROM_CKPT*
# I0413 16:05:18.503059 140719534966592 run_nq_ensemble.py:1239]   name = bert/pooler/dense/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0413 16:05:18.503129 140719534966592 run_nq_ensemble.py:1239]   name = cls/nq/output_weights:0, shape = (2, 1024), *INIT_FROM_CKPT*
# I0413 16:05:18.503201 140719534966592 run_nq_ensemble.py:1239]   name = cls/nq/output_bias:0, shape = (2,), *INIT_FROM_CKPT*
# I0413 16:05:18.503271 140719534966592 run_nq_ensemble.py:1239]   name = answer_type_output_weights:0, shape = (5, 1024), *INIT_FROM_CKPT*
# I0413 16:05:18.503345 140719534966592 run_nq_ensemble.py:1239]   name = answer_type_output_bias:0, shape = (5,), *INIT_FROM_CKPT*
# I0413 16:05:18.503905 140719534966592 estimator.py:1147] Done calling model_fn.
# I0413 16:05:19.647438 140719534966592 monitored_session.py:240] Graph was finalized.
# 2020-04-13 16:05:19.648169: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 16:05:19.648505: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-04-13 16:05:19.648581: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2020-04-13 16:05:19.648600: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2020-04-13 16:05:19.648614: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2020-04-13 16:05:19.648638: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2020-04-13 16:05:19.648653: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2020-04-13 16:05:19.648677: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2020-04-13 16:05:19.648698: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2020-04-13 16:05:19.648808: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 16:05:19.649140: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 16:05:19.649392: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2020-04-13 16:05:19.649437: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-13 16:05:19.649453: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2020-04-13 16:05:19.649468: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2020-04-13 16:05:19.649676: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 16:05:19.650016: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 16:05:19.650291: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15190 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# I0413 16:05:21.678176 140719534966592 session_manager.py:500] Running local_init_op.
# I0413 16:05:21.769756 140719534966592 session_manager.py:502] Done running local_init_op.
# I0413 16:05:23.887660 140719534966592 run_nq_ensemble.py:1484] Processing example: 0
#  31%|███       | 993/3185 [01:18<02:27, 14.89it/s] I0413 16:06:31.037870 140719534966592 run_nq_ensemble.py:1484] Processing example: 1000
#  63%|██████▎   | 1993/3185 [02:25<01:20, 14.90it/s]I0413 16:07:38.177822 140719534966592 run_nq_ensemble.py:1484] Processing example: 2000
#  94%|█████████▍| 2993/3185 [03:32<00:12, 14.90it/s]I0413 16:08:45.338376 140719534966592 run_nq_ensemble.py:1484] Processing example: 3000
# 100%|█████████▉| 3177/3185 [03:45<00:00, 14.90it/s]I0413 16:08:57.330275 140719534966592 error_handling.py:96] prediction_loop marked as finished
# I0413 16:08:57.330509 140719534966592 error_handling.py:96] prediction_loop marked as finished
# 100%|██████████| 3185/3185 [03:45<00:00, 14.14it/s]
# I0413 16:08:57.332358 140719534966592 run_nq_ensemble.py:392] Reading examples from: /data/tiny-dev/nq-dev-sample.no-annot.jsonl.gz
# 2020-04-13 16:09:01.310643: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 16:09:01.311011: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-04-13 16:09:01.311117: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2020-04-13 16:09:01.311141: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2020-04-13 16:09:01.311159: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2020-04-13 16:09:01.311176: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2020-04-13 16:09:01.311194: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2020-04-13 16:09:01.311216: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2020-04-13 16:09:01.311234: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2020-04-13 16:09:01.311370: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 16:09:01.311741: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 16:09:01.312019: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2020-04-13 16:09:01.312067: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-13 16:09:01.312088: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2020-04-13 16:09:01.312106: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2020-04-13 16:09:01.312352: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 16:09:01.313001: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-13 16:09:01.313344: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15190 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# I0413 16:09:01.587513 140719534966592 run_nq_ensemble.py:372] Computing predictions...
# I0413 16:09:02.522340 140719534966592 run_nq_ensemble.py:382] Examples processed: 100
# I0413 16:09:03.325420 140719534966592 run_nq_ensemble.py:382] Examples processed: 200
# I0413 16:09:03.325663 140719534966592 run_nq_ensemble.py:383] Done computing predictions.
# Total time elapsed: 745.9465289115906 seconds
# + python3 -m post_process --predictions_dir=/nq_model/output/ --output_prediction_file=/data/predictions-td-no-annot.json
# W0413 16:09:06.518503 140621404448576 deprecation_wrapper.py:119] From /nq_model/post_process.py:333: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# CPU times: user 12.5 s, sys: 2.9 s, total: 15.4 s
# Wall time: 12min 34s

# %%
# Check that prediction scores are computed as expected
# !python3 -m nq_eval \
  --gold_path="$DATA_DIR/tiny-dev/nq-dev-sample.jsonl.gz" \
  --predictions_path="$DATA_DIR/predictions-td-no-annot.json"
# Out:
# I0413 16:22:33.695448 139893362419072 eval_utils.py:261] parsing /tmp/nq-submission-test-data/tiny-dev/nq-dev-sample.jsonl.gz .....
# I0413 16:22:36.708112 139893362419072 eval_utils.py:213] Reading predictions from file: /tmp/nq-submission-test-data/predictions-td-no-annot.json
# {"long-best-threshold-f1": 0.6976744186046512, "long-best-threshold-precision": 0.6696428571428571, "long-best-threshold-recall": 0.7281553398058253, "long-best-threshold": 2.1822948632972023, "long-recall-at-precision>=0.5": 0.7766990291262136, "long-precision-at-precision>=0.5": 0.5031446540880503, "long-recall-at-precision>=0.75": 0.6310679611650486, "long-precision-at-precision>=0.75": 0.7558139534883721, "long-recall-at-precision>=0.9": 0.20388349514563106, "long-precision-at-precision>=0.9": 0.9130434782608695, "short-best-threshold-f1": 0.6666666666666666, "short-best-threshold-precision": 0.7719298245614035, "short-best-threshold-recall": 0.5866666666666667, "short-best-threshold": 2.89677501107692, "short-recall-at-precision>=0.5": 0.6266666666666667, "short-precision-at-precision>=0.5": 0.5402298850574713, "short-recall-at-precision>=0.75": 0.5866666666666667, "short-precision-at-precision>=0.75": 0.7719298245614035, "short-recall-at-precision>=0.9": 0, "short-precision-at-precision>=0.9": 0}

# %% [markdown]
# #### Docker Build Submission

# %%
# Authenticate and configure project
# !gcloud config set project natural-questions-v1
# Out:
# Updated property [core/project].

# %%
# !gcloud builds submit --tag gcr.io/natural-questions-v1/nq-submission-bert-ensemble-v2 . --timeout=2h15m5s
# Out:
# Creating temporary tarball archive of 39 file(s) totalling 12.5 GiB before compression.
# Uploading tarball of [.] to [gs://natural-questions-v1_cloudbuild/source/1586755726.21-0d1eb827d6d74df5a49323bb3117f22d.tgz]
# Created [https://cloudbuild.googleapis.com/v1/projects/natural-questions-v1/builds/0d796192-d1e7-4c25-b432-f5031931a010].
# Logs are available at [https://console.cloud.google.com/cloud-build/builds/0d796192-d1e7-4c25-b432-f5031931a010?project=512516930043].
# ----------------------------- REMOTE BUILD OUTPUT ------------------------------
# starting build "0d796192-d1e7-4c25-b432-f5031931a010"
#
# FETCHSOURCE
# Fetching storage object: gs://natural-questions-v1_cloudbuild/source/1586755726.21-0d1eb827d6d74df5a49323bb3117f22d.tgz#1586756601374076
# Copying gs://natural-questions-v1_cloudbuild/source/1586755726.21-0d1eb827d6d74df5a49323bb3117f22d.tgz#1586756601374076...
# / [1 files][ 11.4 GiB/ 11.4 GiB]   58.3 MiB/s
# Operation completed over 1 objects/11.4 GiB.
# BUILD
# Already have image (with digest): gcr.io/cloud-builders/docker
# Sending build context to Docker daemon  13.42GB
# Step 1/6 : FROM tensorflow/tensorflow:1.14.0-gpu-py3
# 1.14.0-gpu-py3: Pulling from tensorflow/tensorflow
# 6abc03819f3e: Pulling fs layer
# 05731e63f211: Pulling fs layer
# 0bd67c50d6be: Pulling fs layer
# d5c73556cc1e: Pulling fs layer
# e059dd98ac7c: Pulling fs layer
# e4732fdd9b39: Pulling fs layer
# cbeb255d6ab1: Pulling fs layer
# 0809e577f6d6: Pulling fs layer
# 421e23cecfe8: Pulling fs layer
# a5abf0996067: Pulling fs layer
# d718e4299c08: Pulling fs layer
# f401bdaa92ad: Pulling fs layer
# 6669e38ab1ba: Pulling fs layer
# 5b6ac7f35d3d: Pulling fs layer
# d5c73556cc1e: Waiting
# e059dd98ac7c: Waiting
# e4732fdd9b39: Waiting
# cbeb255d6ab1: Waiting
# 0809e577f6d6: Waiting
# 421e23cecfe8: Waiting
# d718e4299c08: Waiting
# f401bdaa92ad: Waiting
# 6669e38ab1ba: Waiting
# 5b6ac7f35d3d: Waiting
# a5abf0996067: Waiting
# 05731e63f211: Verifying Checksum
# 05731e63f211: Download complete
# 0bd67c50d6be: Verifying Checksum
# 0bd67c50d6be: Download complete
# 6abc03819f3e: Verifying Checksum
# 6abc03819f3e: Download complete
# e059dd98ac7c: Verifying Checksum
# e059dd98ac7c: Download complete
# e4732fdd9b39: Verifying Checksum
# e4732fdd9b39: Download complete
# d5c73556cc1e: Verifying Checksum
# d5c73556cc1e: Download complete
# 421e23cecfe8: Verifying Checksum
# 421e23cecfe8: Download complete
# a5abf0996067: Verifying Checksum
# a5abf0996067: Download complete
# d718e4299c08: Verifying Checksum
# d718e4299c08: Download complete
# 0809e577f6d6: Verifying Checksum
# 0809e577f6d6: Download complete
# 6669e38ab1ba: Verifying Checksum
# 6669e38ab1ba: Download complete
# 5b6ac7f35d3d: Verifying Checksum
# 5b6ac7f35d3d: Download complete
# 6abc03819f3e: Pull complete
# cbeb255d6ab1: Verifying Checksum
# cbeb255d6ab1: Download complete
# f401bdaa92ad: Download complete
# 05731e63f211: Pull complete
# 0bd67c50d6be: Pull complete
# d5c73556cc1e: Pull complete
# e059dd98ac7c: Pull complete
# e4732fdd9b39: Pull complete
# cbeb255d6ab1: Pull complete
# 0809e577f6d6: Pull complete
# 421e23cecfe8: Pull complete
# a5abf0996067: Pull complete
# d718e4299c08: Pull complete
# f401bdaa92ad: Pull complete
# 6669e38ab1ba: Pull complete
# 5b6ac7f35d3d: Pull complete
# Digest: sha256:e72e66b3dcb9c9e8f4e5703965ae1466b23fe8cad59e1c92c6e9fa58f8d81dc8
# Status: Downloaded newer image for tensorflow/tensorflow:1.14.0-gpu-py3
#  ---> a7a1861d2150
# Step 2/6 : RUN pip install --upgrade pip
#  ---> Running in 4f966d7eac80
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/54/0c/d01aa759fdc501a58f431eb594a17495f15b88da142ce14b5845662c13f3/pip-20.0.2-py2.py3-none-any.whl (1.4MB)
# Installing collected packages: pip
#   Found existing installation: pip 19.1.1
#     Uninstalling pip-19.1.1:
#       Successfully uninstalled pip-19.1.1
# Successfully installed pip-20.0.2
# Removing intermediate container 4f966d7eac80
#  ---> 347e4324abf1
# Step 3/6 : RUN pip install --trusted-host pypi.python.org tqdm
#  ---> Running in 463f336c33f9
# Collecting tqdm
#   Downloading tqdm-4.45.0-py2.py3-none-any.whl (60 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.45.0
# Removing intermediate container 463f336c33f9
#  ---> 575fedd10782
# Step 4/6 : RUN pip install --trusted-host pypi.python.org bert-tensorflow
#  ---> Running in 2a33e80414df
# Collecting bert-tensorflow
#   Downloading bert_tensorflow-1.0.1-py2.py3-none-any.whl (67 kB)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from bert-tensorflow) (1.11.0)
# Installing collected packages: bert-tensorflow
# Successfully installed bert-tensorflow-1.0.1
# Removing intermediate container 2a33e80414df
#  ---> 3e4fd3f4f59f
# Step 5/6 : RUN pip install --trusted-host pypi.python.org natural-questions --no-dependencies
#  ---> Running in 842898124de9
# Collecting natural-questions
#   Downloading natural_questions-1.0.4-py2.py3-none-any.whl (22 kB)
# Installing collected packages: natural-questions
# Successfully installed natural-questions-1.0.4
# Removing intermediate container 842898124de9
#  ---> 3ed4bda2a6dd
# Step 6/6 : ADD . /nq_model
#  ---> 4a400b5349c7
# Successfully built 4a400b5349c7
# Successfully tagged gcr.io/natural-questions-v1/nq-submission-bert-joint-v2:latest
# PUSH
# Pushing gcr.io/natural-questions-v1/nq-submission-bert-joint-v2
# The push refers to repository [gcr.io/natural-questions-v1/nq-submission-bert-joint-v2]
# 6d7436d0d920: Preparing
# c81ef1cc1ca3: Preparing
# 39a931d7fc38: Preparing
# 3c53755fd499: Preparing
# ca257612b76e: Preparing
# ac5349f9af57: Preparing
# 47a79b5a2369: Preparing
# 42958de951d6: Preparing
# 6effad8e07e5: Preparing
# 62cbb606ac4a: Preparing
# 8c93aa82e26a: Preparing
# 4b9202833b21: Preparing
# 20048f8d31de: Preparing
# c890837d995f: Preparing
# fcd654f1dc27: Preparing
# becec4c05380: Preparing
# 8d267010480f: Preparing
# 270f934787ed: Preparing
# 02571d034293: Preparing
# ac5349f9af57: Waiting
# 47a79b5a2369: Waiting
# 42958de951d6: Waiting
# 6effad8e07e5: Waiting
# 62cbb606ac4a: Waiting
# 8c93aa82e26a: Waiting
# 4b9202833b21: Waiting
# 20048f8d31de: Waiting
# c890837d995f: Waiting
# fcd654f1dc27: Waiting
# becec4c05380: Waiting
# 8d267010480f: Waiting
# 270f934787ed: Waiting
# 02571d034293: Waiting
# c81ef1cc1ca3: Pushed
# 39a931d7fc38: Pushed
# 3c53755fd499: Pushed
# 47a79b5a2369: Layer already exists
# ac5349f9af57: Layer already exists
# 42958de951d6: Layer already exists
# 62cbb606ac4a: Layer already exists
# ca257612b76e: Pushed
# 6effad8e07e5: Layer already exists
# 8c93aa82e26a: Layer already exists
# 20048f8d31de: Layer already exists
# 4b9202833b21: Layer already exists
# c890837d995f: Layer already exists
# fcd654f1dc27: Layer already exists
# becec4c05380: Layer already exists
# 270f934787ed: Layer already exists
# 8d267010480f: Layer already exists
# 02571d034293: Layer already exists
# 6d7436d0d920: Pushed
# latest: digest: sha256:57055dae34504db8195f2422104dbd42c6b5e9dd5e8875ee7731035b23303c95 size: 4314
# DONE
# --------------------------------------------------------------------------------
#
# ID                                    CREATE_TIME                DURATION  SOURCE                                                                                          IMAGES                                                             STATUS
# 0d796192-d1e7-4c25-b432-f5031931a010  2020-04-13T05:43:22+00:00  29M3S     gs://natural-questions-v1_cloudbuild/source/1586755726.21-0d1eb827d6d74df5a49323bb3117f22d.tgz  gcr.io/natural-questions-v1/nq-submission-bert-joint-v2 (+1 more)  SUCCESS

# %% [markdown]
# #### Official Attempt Submission to Google Natural Questons Competition Results

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; ![](img/my_dashboard.PNG)
# ![](img/official_scores.png)
